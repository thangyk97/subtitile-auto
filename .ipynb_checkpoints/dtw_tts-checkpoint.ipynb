# %%
import matplotlib.pyplot as plt
import librosa
from scipy.io import wavfile
import numpy as np
import os
import re

# %%
# %matplotlib notebook

# %%
data_test, fs_test = librosa.load("/home/thangnd/Videos/first_sent.wav", sr=100000)

# %%
data, fs = librosa.load('/home/thangnd/Videos/banks.wav', sr=100000)

# %%
mfcc = librosa.feature.mfcc(y=data, sr=fs, S=None, n_mfcc=40, dct_type=2, norm='ortho')

# %%
mfcc.shape
# Out:
# (40, 11725)

# %%
plt.imshow(mfcc)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplot(211)
plt.plot(data[fs*54:])
plt.subplot(212)
plt.plot(data_test)
# Out:
# <img src="data:image/png;base64,..." width="640">
